# %%
# !pip install pandas matplotlib seaborn missingno
# Out:
# ...
#
# [notice] A new release of pip is available: 24.0 -> 25.3
# [notice] To update, run: pip install --upgrade pip

# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# ## 1.1 Data Import

# %%
import pandas as pd
train_df = pd.read_csv('Dataset/train.csv')
test_df = pd.read_csv('Dataset/test.csv')

# %%
train_df.info()
test_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 593994 entries, 0 to 593993
# Data columns (total 13 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   id                    593994 non-null  int64
#  1   annual_income         593994 non-null  float64
#  2   debt_to_income_ratio  593994 non-null  float64
#  3   credit_score          593994 non-null  int64
#  4   loan_amount           593994 non-null  float64
#  5   interest_rate         593994 non-null  float64
#  6   gender                593994 non-null  object
#  7   marital_status        593994 non-null  object
#  8   education_level       593994 non-null  object
#  9   employment_status     593994 non-null  object
#  10  loan_purpose          593994 non-null  object
#  11  grade_subgrade        593994 non-null  object
#  12  loan_paid_back        593994 non-null  float64
# dtypes: float64(5), int64(2), object(6)
# memory usage: 58.9+ MB
# ...

# %%
train_df.drop("id", axis=1, inplace=True)
test_df.drop("id", axis=1, inplace=True)

# %%
train_df.info()
test_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 593994 entries, 0 to 593993
# Data columns (total 12 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   annual_income         593994 non-null  float64
#  1   debt_to_income_ratio  593994 non-null  float64
#  2   credit_score          593994 non-null  int64
#  3   loan_amount           593994 non-null  float64
#  4   interest_rate         593994 non-null  float64
#  5   gender                593994 non-null  object
#  6   marital_status        593994 non-null  object
#  7   education_level       593994 non-null  object
#  8   employment_status     593994 non-null  object
#  9   loan_purpose          593994 non-null  object
#  10  grade_subgrade        593994 non-null  object
#  11  loan_paid_back        593994 non-null  float64
# dtypes: float64(5), int64(1), object(6)
# memory usage: 54.4+ MB
# <class 'pandas.core.frame.DataFrame'>
# ...

# %% [markdown]
# ## 1.2 Checking missing values

# %%
import missingno as msno
import matplotlib.pyplot as plt
import seaborn as sns
msno.matrix(train_df)
plt.show()

# %%
msno.matrix(test_df)
plt.show()

# %%
# count missing values in train dataset
missing_train = train_df.isnull().sum()
missing_train
# Out:
# annual_income           0
# debt_to_income_ratio    0
# credit_score            0
# loan_amount             0
# interest_rate           0
# gender                  0
# marital_status          0
# education_level         0
# employment_status       0
# loan_purpose            0
# grade_subgrade          0
# loan_paid_back          0
# dtype: int64

# %%
# count missing values in test dataset
missing_test = test_df.isnull().sum()
missing_test
# Out:
# annual_income           0
# debt_to_income_ratio    0
# credit_score            0
# loan_amount             0
# interest_rate           0
# gender                  0
# marital_status          0
# education_level         0
# employment_status       0
# loan_purpose            0
# grade_subgrade          0
# dtype: int64

# %% [markdown]
# ## 1.3 Categorical and numerical statistical summary

# %%
categorical_cols = train_df.select_dtypes(include=['object']).columns
numerical_cols = train_df.select_dtypes(include=['number']).columns
print("Categorical columns:", categorical_cols)
print("Numerical columns:", numerical_cols)
# Out:
# Categorical columns: Index(['gender', 'marital_status', 'education_level', 'employment_status',
#        'loan_purpose', 'grade_subgrade'],
#       dtype='object')
# Numerical columns: Index(['annual_income', 'debt_to_income_ratio', 'credit_score', 'loan_amount',
#        'interest_rate', 'loan_paid_back'],
#       dtype='object')

# %%
print(len(categorical_cols))
print(len(numerical_cols))
# Out:
# 6
# 6

# %%
train_df[categorical_cols].describe()
# Out:
#         gender marital_status education_level employment_status  \
# count   593994         593994          593994            593994
# unique       3              4               5                 5
# top     Female         Single      Bachelor's          Employed
# freq    306175         288843          279606            450645
#
#               loan_purpose grade_subgrade
# count               593994         593994
# unique                   8             30
# top     Debt consolidation             C3
# freq                324695          58695

# %%
# plot the categorical columns distributions
for col in categorical_cols:
    plt.figure(figsize=(10, 5))
    sns.countplot(data=train_df, x=col)
    plt.title(f'Distribution of {col}')
    plt.xticks(rotation=45)
    plt.show()

# %%
train_df[numerical_cols].describe()
# Out:
#        annual_income  debt_to_income_ratio   credit_score    loan_amount  \
# count  593994.000000         593994.000000  593994.000000  593994.000000
# mean    48212.202976              0.120696     680.916009   15020.297629
# std     26711.942078              0.068573      55.424956    6926.530568
# min      6002.430000              0.011000     395.000000     500.090000
# 25%     27934.400000              0.072000     646.000000   10279.620000
# 50%     46557.680000              0.096000     682.000000   15000.220000
# 75%     60981.320000              0.156000     719.000000   18858.580000
# max    393381.740000              0.627000     849.000000   48959.950000
#
#        interest_rate  loan_paid_back
# count  593994.000000   593994.000000
# mean       12.356345        0.798820
# std         2.008959        0.400883
# min         3.200000        0.000000
# 25%        10.990000        1.000000
# 50%        12.370000        1.000000
# 75%        13.680000        1.000000
# ...

# %%
train_df[numerical_cols].hist(bins=200, figsize=(15, 10))
plt.suptitle('Numerical Columns Distribution')
# Out:
# Text(0.5, 0.98, 'Numerical Columns Distribution')

# %%
# do the qq plots for numerical columns in grid instead of single
import scipy.stats as stats
import numpy as np
num_cols = len(numerical_cols)
cols = 2
rows = int(np.ceil(num_cols / cols))
plt.figure(figsize=(cols * 5, rows * 5))
for i, col in enumerate(numerical_cols):
    plt.subplot(rows, cols, i + 1)
    stats.probplot(train_df[col].dropna(), dist="norm", plot=plt)
    plt.title(f'Q-Q plot of {col}')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 1.4 By target proportion feature exploration

# %%
# print the proportion of target variable
target_counts = train_df['loan_paid_back'].value_counts(normalize=True)
print("Proportion of target variable:")
print(target_counts)
# Out:
# Proportion of target variable:
# loan_paid_back
# 1.0    0.79882
# 0.0    0.20118
# Name: proportion, dtype: float64

# %%
# proportion of target variable by categorical features
for col in categorical_cols:
    plt.figure(figsize=(10, 5))
    sns.countplot(data=train_df, x=col, hue='loan_paid_back')
    plt.title(f'Proportion of target by {col}')
    plt.xticks(rotation=45)
    plt.show()

# %%
# By target proportion feature exploration for numerical features
for col in numerical_cols:
    plt.figure(figsize=(10, 5))
    sns.kdeplot(data=train_df, x=col, hue='loan_paid_back', common_norm=False)
    plt.title(f'Distribution of {col} by target')
    plt.show()
# Out:
# /var/folders/2b/pt5khvbj7n7bn912dnlhbl8c0000gn/T/ipykernel_20161/1621237550.py:4: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(data=train_df, x=col, hue='loan_paid_back', common_norm=False)

# %% [markdown]
# ## 1.5 Correlation metric

# %%
# print the skewness of numerical columns
for col in numerical_cols:
    skewness = train_df[col].skew()
    print(f'Skewness of {col}: {skewness}')
# Out:
# Skewness of annual_income: 1.719508683164502
# Skewness of debt_to_income_ratio: 1.4066799385489641
# Skewness of credit_score: -0.16699288130471676
# Skewness of loan_amount: 0.2073598200202166
# Skewness of interest_rate: 0.04994531465334617
# Skewness of loan_paid_back: -1.4908117063413266

# %%
# correlation matrix against target variable
correlation_matrix = train_df[numerical_cols].corr()
target_correlation = correlation_matrix['loan_paid_back'].sort_values(ascending=False)
print("Correlation of numerical features with target variable:")
print(target_correlation)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[28], line 2
#       1 # correlation matrix against target variable
# ----> 2 correlation_matrix = train_df.corr()
#       3 target_correlation = correlation_matrix['loan_paid_back'].sort_values(ascending=False)
#       4 print("Correlation of numerical features with target variable:")
#
# File ~/Documents/Work/Competition/Predicting loan payback/Predicting-Loan-Payback-Competition/venv/lib/python3.11/site-packages/pandas/core/frame.py:11076, in DataFrame.corr(self, method, min_periods, numeric_only)
#   11074 cols = data.columns
#   11075 idx = cols.copy()
# > 11076 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   11078 if method == "pearson":
#   11079     correl = libalgos.nancorr(mat, minp=min_periods)
#
# ...
